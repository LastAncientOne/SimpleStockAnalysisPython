# %% [markdown]
# # Simple Fundamental Analysis

# %%
from yahoofinancials import YahooFinancials

# %%
ticker = 'AMD'
yahoo_financials = YahooFinancials(ticker)

# %%
balance_sheet_data_qt = yahoo_financials.get_financial_stmts('quarterly', 'balance')
balance_sheet_data_qt
# Out:
# {'balanceSheetHistoryQuarterly': {'AMD': [{'2018-09-29': {'accountsPayable': 1041000000,
#      'capitalSurplus': 8666000000,
#      'cash': 1046000000,
#      'commonStock': 10000000,
#      'goodWill': 289000000,
#      'intangibleAssets': 274000000,
#      'inventory': 738000000,
#      'longTermDebt': 1167000000,
#      'longTermInvestments': 58000000,
#      'netReceivables': 1245000000,
#      'netTangibleAssets': 562000000,
#      'otherAssets': 94000000,
#      'otherCurrentAssets': 200000000,
#      'otherCurrentLiab': 58000000,
#      'otherLiab': 177000000,
#      'otherStockholderEquity': -10000000,
#      'propertyPlantEquipment': 318000000,
#      'retainedEarnings': -7474000000,
#      'shortLongTermDebt': 136000000,
#      'shortTermInvestments': 10000000,
#      'totalAssets': 4347000000,
#      'totalCurrentAssets': 3314000000,
#      'totalCurrentLiabilities': 1878000000,
#      'totalLiab': 3222000000,
#      'totalStockholderEquity': 1125000000,
#      'treasuryStock': -77000000}},
#    {'2018-06-30': {'accountsPayable': 995000000,
#      'capitalSurplus': 8564000000,
#      'cash': 948000000,
#      'commonStock': 10000000,
#      'goodWill': 289000000,
#      'intangibleAssets': 292000000,
#      'inventory': 750000000,
#      'longTermDebt': 1170000000,
#      'longTermInvestments': 57000000,
#      'netReceivables': 1118000000,
#      'netTangibleAssets': 298000000,
#      'otherAssets': 71000000,
#      'otherCurrentAssets': 155000000,
#      'otherCurrentLiab': 113000000,
#      'otherLiab': 186000000,
#      'otherStockholderEquity': -10000000,
#      'propertyPlantEquipment': 295000000,
#      'retainedEarnings': -7576000000,
#      'shortLongTermDebt': 223000000,
#      'shortTermInvestments': 35000000,
#      'totalAssets': 4103000000,
#      'totalCurrentAssets': 3099000000,
#      'totalCurrentLiabilities': 1868000000,
#      'totalLiab': 3224000000,
#      'totalStockholderEquity': 879000000,
#      'treasuryStock': -119000000}},
#    {'2018-03-31': {'accountsPayable': 830000000,
#      'capitalSurplus': 8502000000,
#      'cash': 1045000000,
#      'commonStock': 10000000,
#      'goodWill': 289000000,
#      'intangibleAssets': 308000000,
#      'inventory': 715000000,
#      'longTermDebt': 1165000000,
#      'longTermInvestments': 57000000,
#      'netReceivables': 745000000,
#      'netTangibleAssets': 118000000,
#      'otherAssets': 68000000,
#      'otherCurrentAssets': 168000000,
#      'otherCurrentLiab': 213000000,
#      'otherLiab': 186000000,
#      'otherStockholderEquity': 3000000,
#      'propertyPlantEquipment': 290000000,
#      'retainedEarnings': -7692000000,
#      'shortLongTermDebt': 223000000,
#      'totalAssets': 3763000000,
#      'totalCurrentAssets': 2751000000,
#      'totalCurrentLiabilities': 1697000000,
#      'totalLiab': 3048000000,
#      'totalStockholderEquity': 715000000,
#      'treasuryStock': -105000000}},
#    {'2017-12-30': {'accountsPayable': 796000000,
#      'capitalSurplus': 8464000000,
#      'cash': 1185000000,
#      'commonStock': 9000000,
#      'deferredLongTermAssetCharges': 11000000,
#      'goodWill': 289000000,
#      'intangibleAssets': 239000000,
#      'inventory': 739000000,
#      'longTermDebt': 1325000000,
#      'longTermInvestments': 58000000,
#      'netReceivables': 403000000,
#      'netTangibleAssets': 83000000,
#      'otherAssets': 71000000,
#      'otherCurrentAssets': 188000000,
#      'otherCurrentLiab': 120000000,
#      'otherLiab': 118000000,
#      'otherStockholderEquity': 6000000,
#      'propertyPlantEquipment': 261000000,
#      'retainedEarnings': -7760000000,
#      'shortLongTermDebt': 70000000,
#      'totalAssets': 3540000000,
#      'totalCurrentAssets': 2622000000,
#      'totalCurrentLiabilities': 1486000000,
#      'totalLiab': 2929000000,
#      'totalStockholderEquity': 611000000,
#      'treasuryStock': -102000000}}]}}

# %%
income_statement_data_qt = yahoo_financials.get_financial_stmts('quarterly', 'income')
income_statement_data_qt
# Out:
# {'incomeStatementHistoryQuarterly': {'AMD': [{'2018-09-29': {'costOfRevenue': 992000000,
#      'discontinuedOperations': None,
#      'ebit': 150000000,
#      'effectOfAccountingCharges': None,
#      'extraordinaryItems': None,
#      'grossProfit': 661000000,
#      'incomeBeforeTax': 114000000,
#      'incomeTaxExpense': 12000000,
#      'interestExpense': -30000000,
#      'minorityInterest': None,
#      'netIncome': 102000000,
#      'netIncomeApplicableToCommonShares': 102000000,
#      'netIncomeFromContinuingOps': 102000000,
#      'nonRecurring': None,
#      'operatingIncome': 150000000,
#      'otherItems': None,
#      'otherOperatingExpenses': None,
#      'researchDevelopment': 363000000,
#      'sellingGeneralAdministrative': 148000000,
#      'totalOperatingExpenses': 1503000000,
#      'totalOtherIncomeExpenseNet': -36000000,
#      'totalRevenue': 1653000000}},
#    {'2018-06-30': {'costOfRevenue': 1104000000,
#      'discontinuedOperations': None,
#      'ebit': 153000000,
#      'effectOfAccountingCharges': None,
#      'extraordinaryItems': None,
#      'grossProfit': 652000000,
#      'incomeBeforeTax': 122000000,
#      'incomeTaxExpense': 6000000,
#      'interestExpense': -31000000,
#      'minorityInterest': None,
#      'netIncome': 116000000,
#      'netIncomeApplicableToCommonShares': 116000000,
#      'netIncomeFromContinuingOps': 116000000,
#      'nonRecurring': None,
#      'operatingIncome': 153000000,
#      'otherItems': None,
#      'otherOperatingExpenses': None,
#      'researchDevelopment': 357000000,
#      'sellingGeneralAdministrative': 142000000,
#      'totalOperatingExpenses': 1603000000,
#      'totalOtherIncomeExpenseNet': -31000000,
#      'totalRevenue': 1756000000}},
#    {'2018-03-31': {'costOfRevenue': 1050000000,
#      'discontinuedOperations': None,
#      'ebit': 120000000,
#      'effectOfAccountingCharges': None,
#      'extraordinaryItems': None,
#      'grossProfit': 597000000,
#      'incomeBeforeTax': 89000000,
#      'incomeTaxExpense': 8000000,
#      'interestExpense': -31000000,
#      'minorityInterest': None,
#      'netIncome': 81000000,
#      'netIncomeApplicableToCommonShares': 81000000,
#      'netIncomeFromContinuingOps': 81000000,
#      'nonRecurring': None,
#      'operatingIncome': 120000000,
#      'otherItems': None,
#      'otherOperatingExpenses': None,
#      'researchDevelopment': 343000000,
#      'sellingGeneralAdministrative': 134000000,
#      'totalOperatingExpenses': 1527000000,
#      'totalOtherIncomeExpenseNet': -31000000,
#      'totalRevenue': 1647000000}},
#    {'2017-12-30': {'costOfRevenue': 965000000,
#      'discontinuedOperations': None,
#      'ebit': 82000000,
#      'effectOfAccountingCharges': None,
#      'extraordinaryItems': None,
#      'grossProfit': 515000000,
#      'incomeBeforeTax': 53000000,
#      'incomeTaxExpense': -8000000,
#      'interestExpense': -31000000,
#      'minorityInterest': None,
#      'netIncome': 61000000,
#      'netIncomeApplicableToCommonShares': 61000000,
#      'netIncomeFromContinuingOps': 61000000,
#      'nonRecurring': None,
#      'operatingIncome': 82000000,
#      'otherItems': None,
#      'otherOperatingExpenses': None,
#      'researchDevelopment': 300000000,
#      'sellingGeneralAdministrative': 133000000,
#      'totalOperatingExpenses': 1398000000,
#      'totalOtherIncomeExpenseNet': -29000000,
#      'totalRevenue': 1480000000}}]}}

# %%
all_statement_data_qt =  yahoo_financials.get_financial_stmts('quarterly', ['income', 'cash', 'balance'])
all_statement_data_qt
# Out:
# {'balanceSheetHistoryQuarterly': {'AMD': [{'2018-09-29': {'accountsPayable': 1041000000,
#      'capitalSurplus': 8666000000,
#      'cash': 1046000000,
#      'commonStock': 10000000,
#      'goodWill': 289000000,
#      'intangibleAssets': 274000000,
#      'inventory': 738000000,
#      'longTermDebt': 1167000000,
#      'longTermInvestments': 58000000,
#      'netReceivables': 1245000000,
#      'netTangibleAssets': 562000000,
#      'otherAssets': 94000000,
#      'otherCurrentAssets': 200000000,
#      'otherCurrentLiab': 58000000,
#      'otherLiab': 177000000,
#      'otherStockholderEquity': -10000000,
#      'propertyPlantEquipment': 318000000,
#      'retainedEarnings': -7474000000,
#      'shortLongTermDebt': 136000000,
#      'shortTermInvestments': 10000000,
#      'totalAssets': 4347000000,
#      'totalCurrentAssets': 3314000000,
#      'totalCurrentLiabilities': 1878000000,
#      'totalLiab': 3222000000,
#      'totalStockholderEquity': 1125000000,
#      'treasuryStock': -77000000}},
#    {'2018-06-30': {'accountsPayable': 995000000,
#      'capitalSurplus': 8564000000,
#      'cash': 948000000,
#      'commonStock': 10000000,
#      'goodWill': 289000000,
#      'intangibleAssets': 292000000,
#      'inventory': 750000000,
#      'longTermDebt': 1170000000,
#      'longTermInvestments': 57000000,
#      'netReceivables': 1118000000,
#      'netTangibleAssets': 298000000,
#      'otherAssets': 71000000,
#      'otherCurrentAssets': 155000000,
#      'otherCurrentLiab': 113000000,
#      'otherLiab': 186000000,
#      'otherStockholderEquity': -10000000,
#      'propertyPlantEquipment': 295000000,
#      'retainedEarnings': -7576000000,
#      'shortLongTermDebt': 223000000,
#      'shortTermInvestments': 35000000,
#      'totalAssets': 4103000000,
#      'totalCurrentAssets': 3099000000,
#      'totalCurrentLiabilities': 1868000000,
#      'totalLiab': 3224000000,
#      'totalStockholderEquity': 879000000,
#      'treasuryStock': -119000000}},
#    {'2018-03-31': {'accountsPayable': 830000000,
#      'capitalSurplus': 8502000000,
#      'cash': 1045000000,
#      'commonStock': 10000000,
#      'goodWill': 289000000,
#      'intangibleAssets': 308000000,
#      'inventory': 715000000,
#      'longTermDebt': 1165000000,
#      'longTermInvestments': 57000000,
#      'netReceivables': 745000000,
#      'netTangibleAssets': 118000000,
#      'otherAssets': 68000000,
#      'otherCurrentAssets': 168000000,
#      'otherCurrentLiab': 213000000,
#      'otherLiab': 186000000,
#      'otherStockholderEquity': 3000000,
#      'propertyPlantEquipment': 290000000,
#      'retainedEarnings': -7692000000,
#      'shortLongTermDebt': 223000000,
#      'totalAssets': 3763000000,
#      'totalCurrentAssets': 2751000000,
#      'totalCurrentLiabilities': 1697000000,
#      'totalLiab': 3048000000,
#      'totalStockholderEquity': 715000000,
#      'treasuryStock': -105000000}},
#    {'2017-12-30': {'accountsPayable': 796000000,
#      'capitalSurplus': 8464000000,
#      'cash': 1185000000,
#      'commonStock': 9000000,
#      'deferredLongTermAssetCharges': 11000000,
#      'goodWill': 289000000,
#      'intangibleAssets': 239000000,
#      'inventory': 739000000,
#      'longTermDebt': 1325000000,
#      'longTermInvestments': 58000000,
#      'netReceivables': 403000000,
#      'netTangibleAssets': 83000000,
#      'otherAssets': 71000000,
#      'otherCurrentAssets': 188000000,
#      'otherCurrentLiab': 120000000,
#      'otherLiab': 118000000,
#      'otherStockholderEquity': 6000000,
#      'propertyPlantEquipment': 261000000,
#      'retainedEarnings': -7760000000,
#      'shortLongTermDebt': 70000000,
#      'totalAssets': 3540000000,
#      'totalCurrentAssets': 2622000000,
#      'totalCurrentLiabilities': 1486000000,
#      'totalLiab': 2929000000,
#      'totalStockholderEquity': 611000000,
#      'treasuryStock': -102000000}}]},
#  'cashflowStatementHistoryQuarterly': {'AMD': [{'2018-09-29': {'capitalExpenditures': -33000000,
#      'changeInCash': 95000000,
#      'changeToAccountReceivables': -89000000,
#      'changeToInventory': 12000000,
#      'changeToLiabilities': 12000000,
#      'changeToNetincome': 45000000,
#      'changeToOperatingActivities': -37000000,
#      'depreciation': 41000000,
#      'investments': 25000000,
#      'issuanceOfStock': 9000000,
#      'netIncome': 102000000,
#      'otherCashflowsFromFinancingActivities': -1000000,
#      'totalCashFromFinancingActivities': 8000000,
#      'totalCashFromOperatingActivities': 95000000,
#      'totalCashflowsFromInvestingActivities': -8000000}},
#    {'2018-06-30': {'capitalExpenditures': -43000000,
#      'changeInCash': -95000000,
#      'changeToAccountReceivables': -380000000,
#      'changeToInventory': -35000000,
#      'changeToLiabilities': 70000000,
#      'changeToNetincome': 31000000,
#      'changeToOperatingActivities': 101000000,
#      'depreciation': 42000000,
#      'investments': -35000000,
#      'issuanceOfStock': 29000000,
#      'netBorrowings': -1000000,
#      'netIncome': 116000000,
#      'otherCashflowsFromFinancingActivities': -1000000,
#      'totalCashFromFinancingActivities': 28000000,
#      'totalCashFromOperatingActivities': -45000000,
#      'totalCashflowsFromInvestingActivities': -78000000}},
#    {'2018-03-31': {'capitalExpenditures': -46000000,
#      'changeInCash': -140000000,
#      'changeToAccountReceivables': -284000000,
#      'changeToInventory': -21000000,
#      'changeToLiabilities': 39000000,
#      'changeToNetincome': 34000000,
#      'changeToOperatingActivities': 11000000,
#      'depreciation': 44000000,
#      'investments': -35000000,
#      'issuanceOfStock': 6000000,
#      'netBorrowings': -14000000,
#      'netIncome': 81000000,
#      'otherCashflowsFromFinancingActivities': -1000000,
#      'totalCashFromFinancingActivities': -8000000,
#      'totalCashFromOperatingActivities': -86000000,
#      'totalCashflowsFromInvestingActivities': -46000000}},
#    {'2017-12-30': {'capitalExpenditures': -44000000,
#      'changeInCash': 306000000,
#      'changeToAccountReceivables': 371000000,
#      'changeToInventory': 55000000,
#      'changeToLiabilities': -75000000,
#      'changeToNetincome': -7000000,
#      'changeToOperatingActivities': -97000000,
#      'depreciation': 39000000,
#      'investments': 1000000,
#      'issuanceOfStock': 5000000,
#      'netBorrowings': -40000000,
#      'netIncome': 61000000,
#      'otherCashflowsFromFinancingActivities': 1000000,
#      'totalCashFromFinancingActivities': -34000000,
#      'totalCashFromOperatingActivities': 383000000,
#      'totalCashflowsFromInvestingActivities': -43000000}}]},
#  'incomeStatementHistoryQuarterly': {'AMD': [{'2018-09-29': {'costOfRevenue': 992000000,
#      'discontinuedOperations': None,
#      'ebit': 150000000,
#      'effectOfAccountingCharges': None,
#      'extraordinaryItems': None,
#      'grossProfit': 661000000,
#      'incomeBeforeTax': 114000000,
#      'incomeTaxExpense': 12000000,
#      'interestExpense': -30000000,
#      'minorityInterest': None,
#      'netIncome': 102000000,
#      'netIncomeApplicableToCommonShares': 102000000,
#      'netIncomeFromContinuingOps': 102000000,
#      'nonRecurring': None,
#      'operatingIncome': 150000000,
#      'otherItems': None,
#      'otherOperatingExpenses': None,
#      'researchDevelopment': 363000000,
#      'sellingGeneralAdministrative': 148000000,
#      'totalOperatingExpenses': 1503000000,
#      'totalOtherIncomeExpenseNet': -36000000,
#      'totalRevenue': 1653000000}},
#    {'2018-06-30': {'costOfRevenue': 1104000000,
#      'discontinuedOperations': None,
#      'ebit': 153000000,
#      'effectOfAccountingCharges': None,
#      'extraordinaryItems': None,
#      'grossProfit': 652000000,
#      'incomeBeforeTax': 122000000,
#      'incomeTaxExpense': 6000000,
#      'interestExpense': -31000000,
#      'minorityInterest': None,
#      'netIncome': 116000000,
#      'netIncomeApplicableToCommonShares': 116000000,
#      'netIncomeFromContinuingOps': 116000000,
#      'nonRecurring': None,
#      'operatingIncome': 153000000,
#      'otherItems': None,
#      'otherOperatingExpenses': None,
#      'researchDevelopment': 357000000,
#      'sellingGeneralAdministrative': 142000000,
#      'totalOperatingExpenses': 1603000000,
#      'totalOtherIncomeExpenseNet': -31000000,
#      'totalRevenue': 1756000000}},
#    {'2018-03-31': {'costOfRevenue': 1050000000,
#      'discontinuedOperations': None,
#      'ebit': 120000000,
#      'effectOfAccountingCharges': None,
#      'extraordinaryItems': None,
#      'grossProfit': 597000000,
#      'incomeBeforeTax': 89000000,
#      'incomeTaxExpense': 8000000,
#      'interestExpense': -31000000,
#      'minorityInterest': None,
#      'netIncome': 81000000,
#      'netIncomeApplicableToCommonShares': 81000000,
#      'netIncomeFromContinuingOps': 81000000,
#      'nonRecurring': None,
#      'operatingIncome': 120000000,
#      'otherItems': None,
#      'otherOperatingExpenses': None,
#      'researchDevelopment': 343000000,
#      'sellingGeneralAdministrative': 134000000,
#      'totalOperatingExpenses': 1527000000,
#      'totalOtherIncomeExpenseNet': -31000000,
#      'totalRevenue': 1647000000}},
#    {'2017-12-30': {'costOfRevenue': 965000000,
#      'discontinuedOperations': None,
#      'ebit': 82000000,
#      'effectOfAccountingCharges': None,
#      'extraordinaryItems': None,
#      'grossProfit': 515000000,
#      'incomeBeforeTax': 53000000,
#      'incomeTaxExpense': -8000000,
#      'interestExpense': -31000000,
#      'minorityInterest': None,
#      'netIncome': 61000000,
#      'netIncomeApplicableToCommonShares': 61000000,
#      'netIncomeFromContinuingOps': 61000000,
#      'nonRecurring': None,
#      'operatingIncome': 82000000,
#      'otherItems': None,
#      'otherOperatingExpenses': None,
#      'researchDevelopment': 300000000,
#      'sellingGeneralAdministrative': 133000000,
#      'totalOperatingExpenses': 1398000000,
#      'totalOtherIncomeExpenseNet': -29000000,
#      'totalRevenue': 1480000000}}]}}

# %%
stock_earnings_data = yahoo_financials.get_stock_earnings_data()
stock_earnings_data
# Out:
# {'AMD': {'earningsData': {'currentQuarterEstimate': 0.08,
#    'currentQuarterEstimateDate': '4Q',
#    'currentQuarterEstimateYear': 2018,
#    'earningsDate': [{'fmt': '2019-01-29', 'raw': 1548720000}],
#    'quarterly': [{'actual': 0.08, 'date': '4Q2017', 'estimate': 0.05},
#     {'actual': 0.11, 'date': '1Q2018', 'estimate': 0.09},
#     {'actual': 0.14, 'date': '2Q2018', 'estimate': 0.13},
#     {'actual': 0.13, 'date': '3Q2018', 'estimate': 0.12}]},
#   'financialCurrency': 'USD',
#   'financialsData': {'quarterly': [{'date': '4Q2017',
#      'earnings': 61000000,
#      'revenue': 1480000000},
#     {'date': '1Q2018', 'earnings': 81000000, 'revenue': 1647000000},
#     {'date': '2Q2018', 'earnings': 116000000, 'revenue': 1756000000},
#     {'date': '3Q2018', 'earnings': 102000000, 'revenue': 1653000000}],
#    'yearly': [{'date': 2014, 'earnings': -403000000, 'revenue': 5506000000},
#     {'date': 2015, 'earnings': -660000000, 'revenue': 3991000000},
#     {'date': 2016, 'earnings': -497000000, 'revenue': 4272000000},
#     {'date': 2017, 'earnings': 43000000, 'revenue': 5329000000}]}}}

# %%
stock_net_income = yahoo_financials.get_net_income()
stock_net_income
# Out:
# 43000000

# %%
historical_stock_prices = yahoo_financials.get_historical_price_data('2015-01-15', '2017-10-15', 'weekly')
historical_stock_prices
# Out:
# {'AMD': {'currency': 'USD',
#   'eventsData': {},
#   'firstTradeDate': {'date': 322131600, 'formatted_date': '1980-03-17'},
#   'instrumentType': 'EQUITY',
#   'prices': [{'adjclose': 2.390000104904175,
#     'close': 2.390000104904175,
#     'date': 1421038800,
#     'formatted_date': '2015-01-12',
#     'high': 2.6500000953674316,
#     'low': 2.390000104904175,
#     'open': 2.619999885559082,
#     'volume': 47936400},
#    {'adjclose': 2.450000047683716,
#     'close': 2.450000047683716,
#     'date': 1421643600,
#     'formatted_date': '2015-01-19',
#     'high': 2.5,
#     'low': 2.140000104904175,
#     'open': 2.390000104904175,
#     'volume': 150190400},
#    {'adjclose': 2.569999933242798,
#     'close': 2.569999933242798,
#     'date': 1422248400,
#     'formatted_date': '2015-01-26',
#     'high': 2.8399999141693115,
#     'low': 2.440000057220459,
#     'open': 2.440000057220459,
#     'volume': 143860700},
#    {'adjclose': 3.0299999713897705,
#     'close': 3.0299999713897705,
#     'date': 1422853200,
#     'formatted_date': '2015-02-02',
#     'high': 3.369999885559082,
#     'low': 2.6500000953674316,
#     'open': 2.690000057220459,
#     'volume': 194569600},
#    {'adjclose': 3.1500000953674316,
#     'close': 3.1500000953674316,
#     'date': 1423458000,
#     'formatted_date': '2015-02-09',
#     'high': 3.180000066757202,
#     'low': 2.930000066757202,
#     'open': 3.0299999713897705,
#     'volume': 72472600},
#    {'adjclose': 3.059999942779541,
#     'close': 3.059999942779541,
#     'date': 1424062800,
#     'formatted_date': '2015-02-16',
#     'high': 3.1700000762939453,
#     'low': 3.009999990463257,
#     'open': 3.1600000858306885,
#     'volume': 33192300},
#    {'adjclose': 3.109999895095825,
#     'close': 3.109999895095825,
#     'date': 1424667600,
#     'formatted_date': '2015-02-23',
#     'high': 3.140000104904175,
#     'low': 3.0199999809265137,
#     'open': 3.049999952316284,
#     'volume': 39205300},
#    {'adjclose': 2.9200000762939453,
#     'close': 2.9200000762939453,
#     'date': 1425272400,
#     'formatted_date': '2015-03-02',
#     'high': 3.2300000190734863,
#     'low': 2.8299999237060547,
#     'open': 3.130000114440918,
#     'volume': 64652400},
#    {'adjclose': 2.75,
#     'close': 2.75,
#     'date': 1425873600,
#     'formatted_date': '2015-03-09',
#     'high': 2.9800000190734863,
#     'low': 2.7100000381469727,
#     'open': 2.9200000762939453,
#     'volume': 56387800},
#    {'adjclose': 2.799999952316284,
#     'close': 2.799999952316284,
#     'date': 1426478400,
#     'formatted_date': '2015-03-16',
#     'high': 2.819999933242798,
#     'low': 2.7200000286102295,
#     'open': 2.75,
#     'volume': 44829000},
#    {'adjclose': 2.7200000286102295,
#     'close': 2.7200000286102295,
#     'date': 1427083200,
#     'formatted_date': '2015-03-23',
#     'high': 2.8499999046325684,
#     'low': 2.5299999713897705,
#     'open': 2.809999942779541,
#     'volume': 88210100},
#    {'adjclose': 2.690000057220459,
#     'close': 2.690000057220459,
#     'date': 1427688000,
#     'formatted_date': '2015-03-30',
#     'high': 2.759999990463257,
#     'low': 2.6500000953674316,
#     'open': 2.7300000190734863,
#     'volume': 33826500},
#    {'adjclose': 2.759999990463257,
#     'close': 2.759999990463257,
#     'date': 1428292800,
#     'formatted_date': '2015-04-06',
#     'high': 2.7799999713897705,
#     'low': 2.680000066757202,
#     'open': 2.680000066757202,
#     'volume': 31578000},
#    {'adjclose': 2.5799999237060547,
#     'close': 2.5799999237060547,
#     'date': 1428897600,
#     'formatted_date': '2015-04-13',
#     'high': 2.940000057220459,
#     'low': 2.450000047683716,
#     'open': 2.759999990463257,
#     'volume': 118814300},
#    {'adjclose': 2.299999952316284,
#     'close': 2.299999952316284,
#     'date': 1429502400,
#     'formatted_date': '2015-04-20',
#     'high': 2.569999933242798,
#     'low': 2.25,
#     'open': 2.559999942779541,
#     'volume': 118171900},
#    {'adjclose': 2.309999942779541,
#     'close': 2.309999942779541,
#     'date': 1430107200,
#     'formatted_date': '2015-04-27',
#     'high': 2.369999885559082,
#     'low': 2.25,
#     'open': 2.299999952316284,
#     'volume': 59933900},
#    {'adjclose': 2.309999942779541,
#     'close': 2.309999942779541,
#     'date': 1430712000,
#     'formatted_date': '2015-05-04',
#     'high': 2.359999895095825,
#     'low': 2.240000009536743,
#     'open': 2.309999942779541,
#     'volume': 65308200},
#    {'adjclose': 2.319999933242798,
#     'close': 2.319999933242798,
#     'date': 1431316800,
#     'formatted_date': '2015-05-11',
#     'high': 2.390000104904175,
#     'low': 2.299999952316284,
#     'open': 2.309999942779541,
#     'volume': 44560200},
#    {'adjclose': 2.2799999713897705,
#     'close': 2.2799999713897705,
#     'date': 1431921600,
#     'formatted_date': '2015-05-18',
#     'high': 2.369999885559082,
#     'low': 2.2699999809265137,
#     'open': 2.3499999046325684,
#     'volume': 41180700},
#    {'adjclose': 2.2799999713897705,
#     'close': 2.2799999713897705,
#     'date': 1432526400,
#     'formatted_date': '2015-05-25',
#     'high': 2.3299999237060547,
#     'low': 2.200000047683716,
#     'open': 2.2699999809265137,
#     'volume': 47599600},
#    {'adjclose': 2.3299999237060547,
#     'close': 2.3299999237060547,
#     'date': 1433131200,
#     'formatted_date': '2015-06-01',
#     'high': 2.3399999141693115,
#     'low': 2.25,
#     'open': 2.2899999618530273,
#     'volume': 40892600},
#    {'adjclose': 2.309999942779541,
#     'close': 2.309999942779541,
#     'date': 1433736000,
#     'formatted_date': '2015-06-08',
#     'high': 2.359999895095825,
#     'low': 2.2799999713897705,
#     'open': 2.309999942779541,
#     'volume': 38880100},
#    {'adjclose': 2.5799999237060547,
#     'close': 2.5799999237060547,
#     'date': 1434340800,
#     'formatted_date': '2015-06-15',
#     'high': 2.5899999141693115,
#     'low': 2.2899999618530273,
#     'open': 2.319999933242798,
#     'volume': 96872600},
#    {'adjclose': 2.4700000286102295,
#     'close': 2.4700000286102295,
#     'date': 1434945600,
#     'formatted_date': '2015-06-22',
#     'high': 2.6700000762939453,
#     'low': 2.369999885559082,
#     'open': 2.609999895095825,
#     'volume': 170260800},
#    {'adjclose': 2.5299999713897705,
#     'close': 2.5299999713897705,
#     'date': 1435550400,
#     'formatted_date': '2015-06-29',
#     'high': 2.630000114440918,
#     'low': 2.309999942779541,
#     'open': 2.4100000858306885,
#     'volume': 92913700},
#    {'adjclose': 1.9600000381469727,
#     'close': 1.9600000381469727,
#     'date': 1436155200,
#     'formatted_date': '2015-07-06',
#     'high': 2.5399999618530273,
#     'low': 1.9299999475479126,
#     'open': 2.4600000381469727,
#     'volume': 122970000},
#    {'adjclose': 1.7899999618530273,
#     'close': 1.7899999618530273,
#     'date': 1436760000,
#     'formatted_date': '2015-07-13',
#     'high': 2.0899999141693115,
#     'low': 1.7400000095367432,
#     'open': 1.9700000286102295,
#     'volume': 87191400},
#    {'adjclose': 1.6699999570846558,
#     'close': 1.6699999570846558,
#     'date': 1437364800,
#     'formatted_date': '2015-07-20',
#     'high': 1.840000033378601,
#     'low': 1.649999976158142,
#     'open': 1.8200000524520874,
#     'volume': 70340600},
#    {'adjclose': 1.9299999475479126,
#     'close': 1.9299999475479126,
#     'date': 1437969600,
#     'formatted_date': '2015-07-27',
#     'high': 1.9900000095367432,
#     'low': 1.6100000143051147,
#     'open': 1.6699999570846558,
#     'volume': 75684400},
#    {'adjclose': 2.0899999141693115,
#     'close': 2.0899999141693115,
#     'date': 1438574400,
#     'formatted_date': '2015-08-03',
#     'high': 2.2100000381469727,
#     'low': 1.899999976158142,
#     'open': 1.9299999475479126,
#     'volume': 70938400},
#    {'adjclose': 1.840000033378601,
#     'close': 1.840000033378601,
#     'date': 1439179200,
#     'formatted_date': '2015-08-10',
#     'high': 1.9800000190734863,
#     'low': 1.7899999618530273,
#     'open': 1.9199999570846558,
#     'volume': 59922900},
#    {'adjclose': 1.7799999713897705,
#     'close': 1.7799999713897705,
#     'date': 1439784000,
#     'formatted_date': '2015-08-17',
#     'high': 1.8799999952316284,
#     'low': 1.6799999475479126,
#     'open': 1.8200000524520874,
#     'volume': 52530700},
#    {'adjclose': 1.850000023841858,
#     'close': 1.850000023841858,
#     'date': 1440388800,
#     'formatted_date': '2015-08-24',
#     'high': 1.8700000047683716,
#     'low': 1.649999976158142,
#     'open': 1.690000057220459,
#     'volume': 62794300},
#    {'adjclose': 1.8200000524520874,
#     'close': 1.8200000524520874,
#     'date': 1440993600,
#     'formatted_date': '2015-08-31',
#     'high': 1.8700000047683716,
#     'low': 1.7100000381469727,
#     'open': 1.8200000524520874,
#     'volume': 35159800},
#    {'adjclose': 2.009999990463257,
#     'close': 2.009999990463257,
#     'date': 1441598400,
#     'formatted_date': '2015-09-07',
#     'high': 2.140000104904175,
#     'low': 1.809999942779541,
#     'open': 1.850000023841858,
#     'volume': 53857300},
#    {'adjclose': 1.8700000047683716,
#     'close': 1.8700000047683716,
#     'date': 1442203200,
#     'formatted_date': '2015-09-14',
#     'high': 2.0,
#     'low': 1.809999942779541,
#     'open': 2.0,
#     'volume': 45451700},
#    {'adjclose': 1.7100000381469727,
#     'close': 1.7100000381469727,
#     'date': 1442808000,
#     'formatted_date': '2015-09-21',
#     'high': 1.899999976158142,
#     'low': 1.659999966621399,
#     'open': 1.8700000047683716,
#     'volume': 41894500},
#    {'adjclose': 1.8300000429153442,
#     'close': 1.8300000429153442,
#     'date': 1443412800,
#     'formatted_date': '2015-09-28',
#     'high': 1.8300000429153442,
#     'low': 1.649999976158142,
#     'open': 1.690000057220459,
#     'volume': 31084200},
#    {'adjclose': 1.9600000381469727,
#     'close': 1.9600000381469727,
#     'date': 1444017600,
#     'formatted_date': '2015-10-05',
#     'high': 1.9600000381469727,
#     'low': 1.7699999809265137,
#     'open': 1.8200000524520874,
#     'volume': 41841000},
#    {'adjclose': 1.940000057220459,
#     'close': 1.940000057220459,
#     'date': 1444622400,
#     'formatted_date': '2015-10-12',
#     'high': 2.059999942779541,
#     'low': 1.850000023841858,
#     'open': 1.9600000381469727,
#     'volume': 73441300},
#    {'adjclose': 2.2100000381469727,
#     'close': 2.2100000381469727,
#     'date': 1445227200,
#     'formatted_date': '2015-10-19',
#     'high': 2.2100000381469727,
#     'low': 1.909999966621399,
#     'open': 1.909999966621399,
#     'volume': 48930400},
#    {'adjclose': 2.119999885559082,
#     'close': 2.119999885559082,
#     'date': 1445832000,
#     'formatted_date': '2015-10-26',
#     'high': 2.2100000381469727,
#     'low': 2.0999999046325684,
#     'open': 2.2100000381469727,
#     'volume': 28391200},
#    {'adjclose': 2.1500000953674316,
#     'close': 2.1500000953674316,
#     'date': 1446440400,
#     'formatted_date': '2015-11-02',
#     'high': 2.299999952316284,
#     'low': 2.109999895095825,
#     'open': 2.130000114440918,
#     'volume': 36078400},
#    {'adjclose': 1.9900000095367432,
#     'close': 1.9900000095367432,
#     'date': 1447045200,
#     'formatted_date': '2015-11-09',
#     'high': 2.180000066757202,
#     'low': 1.940000057220459,
#     'open': 2.1500000953674316,
#     'volume': 25422500},
#    {'adjclose': 2.2200000286102295,
#     'close': 2.2200000286102295,
#     'date': 1447650000,
#     'formatted_date': '2015-11-16',
#     'high': 2.25,
#     'low': 1.9500000476837158,
#     'open': 1.9900000095367432,
#     'volume': 34790900},
#    {'adjclose': 2.3299999237060547,
#     'close': 2.3299999237060547,
#     'date': 1448254800,
#     'formatted_date': '2015-11-23',
#     'high': 2.4000000953674316,
#     'low': 2.1700000762939453,
#     'open': 2.2200000286102295,
#     'volume': 30244300},
#    {'adjclose': 2.2799999713897705,
#     'close': 2.2799999713897705,
#     'date': 1448859600,
#     'formatted_date': '2015-11-30',
#     'high': 2.369999885559082,
#     'low': 2.200000047683716,
#     'open': 2.3399999141693115,
#     'volume': 34705000},
#    {'adjclose': 2.359999895095825,
#     'close': 2.359999895095825,
#     'date': 1449464400,
#     'formatted_date': '2015-12-07',
#     'high': 2.5,
#     'low': 2.2100000381469727,
#     'open': 2.259999990463257,
#     'volume': 51201400},
#    {'adjclose': 2.450000047683716,
#     'close': 2.450000047683716,
#     'date': 1450069200,
#     'formatted_date': '2015-12-14',
#     'high': 2.5999999046325684,
#     'low': 2.299999952316284,
#     'open': 2.359999895095825,
#     'volume': 63955400},
#    {'adjclose': 2.9200000762939453,
#     'close': 2.9200000762939453,
#     'date': 1450674000,
#     'formatted_date': '2015-12-21',
#     'high': 3.0,
#     'low': 2.430000066757202,
#     'open': 2.4700000286102295,
#     'volume': 73681500},
#    {'adjclose': 2.869999885559082,
#     'close': 2.869999885559082,
#     'date': 1451278800,
#     'formatted_date': '2015-12-28',
#     'high': 3.059999942779541,
#     'low': 2.859999895095825,
#     'open': 2.9100000858306885,
#     'volume': 52360200},
#    {'adjclose': 2.140000104904175,
#     'close': 2.140000104904175,
#     'date': 1451883600,
#     'formatted_date': '2016-01-04',
#     'high': 2.819999933242798,
#     'low': 2.0999999046325684,
#     'open': 2.7699999809265137,
#     'volume': 123274400},
#    {'adjclose': 2.0299999713897705,
#     'close': 2.0299999713897705,
#     'date': 1452488400,
#     'formatted_date': '2016-01-11',
#     'high': 2.4600000381469727,
#     'low': 1.9900000095367432,
#     'open': 2.1600000858306885,
#     'volume': 87225300},
#    {'adjclose': 2.0199999809265137,
#     'close': 2.0199999809265137,
#     'date': 1453093200,
#     'formatted_date': '2016-01-18',
#     'high': 2.180000066757202,
#     'low': 1.75,
#     'open': 2.0799999237060547,
#     'volume': 90855900},
#    {'adjclose': 2.200000047683716,
#     'close': 2.200000047683716,
#     'date': 1453698000,
#     'formatted_date': '2016-01-25',
#     'high': 2.200000047683716,
#     'low': 2.009999990463257,
#     'open': 2.009999990463257,
#     'volume': 54123500},
#    {'adjclose': 1.9800000190734863,
#     'close': 1.9800000190734863,
#     'date': 1454302800,
#     'formatted_date': '2016-02-01',
#     'high': 2.190000057220459,
#     'low': 1.9500000476837158,
#     'open': 2.1700000762939453,
#     'volume': 46211800},
#    {'adjclose': 1.8300000429153442,
#     'close': 1.8300000429153442,
#     'date': 1454907600,
#     'formatted_date': '2016-02-08',
#     'high': 2.0,
#     'low': 1.809999942779541,
#     'open': 1.9700000286102295,
#     'volume': 53497300},
#    {'adjclose': 1.909999966621399,
#     'close': 1.909999966621399,
#     'date': 1455512400,
#     'formatted_date': '2016-02-15',
#     'high': 1.9800000190734863,
#     'low': 1.8200000524520874,
#     'open': 1.8600000143051147,
#     'volume': 44231100},
#    {'adjclose': 2.069999933242798,
#     'close': 2.069999933242798,
#     'date': 1456117200,
#     'formatted_date': '2016-02-22',
#     'high': 2.0999999046325684,
#     'low': 1.9299999475479126,
#     'open': 1.940000057220459,
#     'volume': 37003600},
#    {'adjclose': 2.369999885559082,
#     'close': 2.369999885559082,
#     'date': 1456722000,
#     'formatted_date': '2016-02-29',
#     'high': 2.549999952316284,
#     'low': 2.049999952316284,
#     'open': 2.059999942779541,
#     'volume': 68771500},
#    {'adjclose': 2.5199999809265137,
#     'close': 2.5199999809265137,
#     'date': 1457326800,
#     'formatted_date': '2016-03-07',
#     'high': 2.5399999618530273,
#     'low': 2.1500000953674316,
#     'open': 2.359999895095825,
#     'volume': 62849500},
#    {'adjclose': 2.930000066757202,
#     'close': 2.930000066757202,
#     'date': 1457928000,
#     'formatted_date': '2016-03-14',
#     'high': 2.930000066757202,
#     'low': 2.450000047683716,
#     'open': 2.5299999713897705,
#     'volume': 123768600},
#    {'adjclose': 2.7899999618530273,
#     'close': 2.7899999618530273,
#     'date': 1458532800,
#     'formatted_date': '2016-03-21',
#     'high': 2.9000000953674316,
#     'low': 2.619999885559082,
#     'open': 2.9000000953674316,
#     'volume': 43988000},
#    {'adjclose': 2.8299999237060547,
#     'close': 2.8299999237060547,
#     'date': 1459137600,
#     'formatted_date': '2016-03-28',
#     'high': 2.9800000190734863,
#     'low': 2.700000047683716,
#     'open': 2.809999942779541,
#     'volume': 53524800},
#    {'adjclose': 2.740000009536743,
#     'close': 2.740000009536743,
#     'date': 1459742400,
#     'formatted_date': '2016-04-04',
#     'high': 2.869999885559082,
#     'low': 2.609999895095825,
#     'open': 2.8299999237060547,
#     'volume': 49672900},
#    {'adjclose': 2.700000047683716,
#     'close': 2.700000047683716,
#     'date': 1460347200,
#     'formatted_date': '2016-04-11',
#     'high': 2.8499999046325684,
#     'low': 2.680000066757202,
#     'open': 2.759999990463257,
#     'volume': 49626100},
#    {'adjclose': 3.990000009536743,
#     'close': 3.990000009536743,
#     'date': 1460952000,
#     'formatted_date': '2016-04-18',
#     'high': 3.990000009536743,
#     'low': 2.5999999046325684,
#     'open': 2.6700000762939453,
#     'volume': 185791600},
#    {'adjclose': 3.549999952316284,
#     'close': 3.549999952316284,
#     'date': 1461556800,
#     'formatted_date': '2016-04-25',
#     'high': 3.819999933242798,
#     'low': 3.309999942779541,
#     'open': 3.809999942779541,
#     'volume': 179079400},
#    {'adjclose': 3.680000066757202,
#     'close': 3.680000066757202,
#     'date': 1462161600,
#     'formatted_date': '2016-05-02',
#     'high': 3.799999952316284,
#     'low': 3.5399999618530273,
#     'open': 3.5799999237060547,
#     'volume': 72815000},
#    {'adjclose': 3.6700000762939453,
#     'close': 3.6700000762939453,
#     'date': 1462766400,
#     'formatted_date': '2016-05-09',
#     'high': 3.7300000190734863,
#     'low': 3.450000047683716,
#     'open': 3.6600000858306885,
#     'volume': 58976900},
#    {'adjclose': 3.869999885559082,
#     'close': 3.869999885559082,
#     'date': 1463371200,
#     'formatted_date': '2016-05-16',
#     'high': 3.9800000190734863,
#     'low': 3.6500000953674316,
#     'open': 3.6700000762939453,
#     'volume': 85773300},
#    {'adjclose': 4.599999904632568,
#     'close': 4.599999904632568,
#     'date': 1463976000,
#     'formatted_date': '2016-05-23',
#     'high': 4.630000114440918,
#     'low': 3.880000114440918,
#     'open': 3.9000000953674316,
#     'volume': 151463300},
#    {'adjclose': 4.159999847412109,
#     'close': 4.159999847412109,
#     'date': 1464580800,
#     'formatted_date': '2016-05-30',
#     'high': 4.710000038146973,
#     'low': 4.070000171661377,
#     'open': 4.670000076293945,
#     'volume': 107942100},
#    {'adjclose': 4.320000171661377,
#     'close': 4.320000171661377,
#     'date': 1465185600,
#     'formatted_date': '2016-06-06',
#     'high': 4.670000076293945,
#     'low': 4.170000076293945,
#     'open': 4.199999809265137,
#     'volume': 89405700},
#    {'adjclose': 5.260000228881836,
#     'close': 5.260000228881836,
#     'date': 1465790400,
#     'formatted_date': '2016-06-13',
#     'high': 5.269999980926514,
#     'low': 4.300000190734863,
#     'open': 4.320000171661377,
#     'volume': 140950400},
#    {'adjclose': 4.880000114440918,
#     'close': 4.880000114440918,
#     'date': 1466395200,
#     'formatted_date': '2016-06-20',
#     'high': 5.519999980926514,
#     'low': 4.760000228881836,
#     'open': 5.389999866485596,
#     'volume': 193243600},
#    {'adjclose': 5.070000171661377,
#     'close': 5.070000171661377,
#     'date': 1467000000,
#     'formatted_date': '2016-06-27',
#     'high': 5.400000095367432,
#     'low': 4.650000095367432,
#     'open': 4.880000114440918,
#     'volume': 137745700},
#    {'adjclose': 5.099999904632568,
#     'close': 5.099999904632568,
#     'date': 1467604800,
#     'formatted_date': '2016-07-04',
#     'high': 5.150000095367432,
#     'low': 4.820000171661377,
#     'open': 5.03000020980835,
#     'volume': 79622800},
#    {'adjclose': 5.139999866485596,
#     'close': 5.139999866485596,
#     'date': 1468209600,
#     'formatted_date': '2016-07-11',
#     'high': 5.239999771118164,
#     'low': 5.0,
#     'open': 5.130000114440918,
#     'volume': 90162300},
#    {'adjclose': 5.840000152587891,
#     'close': 5.840000152587891,
#     'date': 1468814400,
#     'formatted_date': '2016-07-18',
#     'high': 5.96999979019165,
#     'low': 5.099999904632568,
#     'open': 5.190000057220459,
#     'volume': 224241700},
#    {'adjclose': 6.860000133514404,
#     'close': 6.860000133514404,
#     'date': 1469419200,
#     'formatted_date': '2016-07-25',
#     'high': 7.159999847412109,
#     'low': 5.920000076293945,
#     'open': 5.929999828338623,
#     'volume': 288169600},
#    {'adjclose': 6.610000133514404,
#     'close': 6.610000133514404,
#     'date': 1470024000,
#     'formatted_date': '2016-08-01',
#     'high': 6.920000076293945,
#     'low': 6.150000095367432,
#     'open': 6.889999866485596,
#     'volume': 133910400},
#    {'adjclose': 6.730000019073486,
#     'close': 6.730000019073486,
#     'date': 1470628800,
#     'formatted_date': '2016-08-08',
#     'high': 6.849999904632568,
#     'low': 6.25,
#     'open': 6.699999809265137,
#     'volume': 105870700},
#    {'adjclose': 7.619999885559082,
#     'close': 7.619999885559082,
#     'date': 1471233600,
#     'formatted_date': '2016-08-15',
#     'high': 8.0,
#     'low': 6.610000133514404,
#     'open': 6.789999961853027,
#     'volume': 174812100},
#    {'adjclose': 7.670000076293945,
#     'close': 7.670000076293945,
#     'date': 1471838400,
#     'formatted_date': '2016-08-22',
#     'high': 7.949999809265137,
#     'low': 7.199999809265137,
#     'open': 7.829999923706055,
#     'volume': 139833400},
#    {'adjclose': 7.510000228881836,
#     'close': 7.510000228881836,
#     'date': 1472443200,
#     'formatted_date': '2016-08-29',
#     'high': 7.789999961853027,
#     'low': 7.090000152587891,
#     'open': 7.71999979019165,
#     'volume': 92611700},
#    {'adjclose': 5.900000095367432,
#     'close': 5.900000095367432,
#     'date': 1473048000,
#     'formatted_date': '2016-09-05',
#     'high': 7.599999904632568,
#     'low': 5.849999904632568,
#     'open': 7.559999942779541,
#     'volume': 344238200},
#    {'adjclose': 6.050000190734863,
#     'close': 6.050000190734863,
#     'date': 1473652800,
#     'formatted_date': '2016-09-12',
#     'high': 6.21999979019165,
#     'low': 5.659999847412109,
#     'open': 5.829999923706055,
#     'volume': 293583900},
#    {'adjclose': 6.550000190734863,
#     'close': 6.550000190734863,
#     'date': 1474257600,
#     'formatted_date': '2016-09-19',
#     'high': 6.650000095367432,
#     'low': 6.079999923706055,
#     'open': 6.119999885559082,
#     'volume': 197123900},
#    {'adjclose': 6.909999847412109,
#     'close': 6.909999847412109,
#     'date': 1474862400,
#     'formatted_date': '2016-09-26',
#     'high': 7.039999961853027,
#     'low': 6.289999961853027,
#     'open': 6.539999961853027,
#     'volume': 165989200},
#    {'adjclose': 6.75,
#     'close': 6.75,
#     'date': 1475467200,
#     'formatted_date': '2016-10-03',
#     'high': 7.150000095367432,
#     'low': 6.619999885559082,
#     'open': 6.949999809265137,
#     'volume': 147581000},
#    {'adjclose': 6.75,
#     'close': 6.75,
#     'date': 1476072000,
#     'formatted_date': '2016-10-10',
#     'high': 7.119999885559082,
#     'low': 6.239999771118164,
#     'open': 6.820000171661377,
#     'volume': 177204300},
#    {'adjclose': 6.519999980926514,
#     'close': 6.519999980926514,
#     'date': 1476676800,
#     'formatted_date': '2016-10-17',
#     'high': 6.980000019073486,
#     'low': 6.369999885559082,
#     'open': 6.920000076293945,
#     'volume': 207626900},
#    {'adjclose': 7.199999809265137,
#     'close': 7.199999809265137,
#     'date': 1477281600,
#     'formatted_date': '2016-10-24',
#     'high': 7.53000020980835,
#     'low': 6.539999961853027,
#     'open': 6.570000171661377,
#     'volume': 294545200},
#    {'adjclose': 6.559999942779541,
#     'close': 6.559999942779541,
#     'date': 1477886400,
#     'formatted_date': '2016-10-31',
#     'high': 7.460000038146973,
#     'low': 6.460000038146973,
#     'open': 7.239999771118164,
#     'volume': 181994300},
#    {'adjclose': 6.690000057220459,
#     'close': 6.690000057220459,
#     'date': 1478494800,
#     'formatted_date': '2016-11-07',
#     'high': 7.179999828338623,
#     'low': 6.21999979019165,
#     'open': 6.789999961853027,
#     'volume': 224321500},
#    {'adjclose': 8.710000038146973,
#     'close': 8.710000038146973,
#     'date': 1479099600,
#     'formatted_date': '2016-11-14',
#     'high': 8.829999923706055,
#     'low': 6.610000133514404,
#     'open': 6.829999923706055,
#     'volume': 323003400},
#    {'adjclose': 8.770000457763672,
#     'close': 8.770000457763672,
#     'date': 1479704400,
#     'formatted_date': '2016-11-21',
#     'high': 9.220000267028809,
#     'low': 8.5,
#     'open': 8.869999885559082,
#     'volume': 185706000},
#    {'adjclose': 8.529999732971191,
#     'close': 8.529999732971191,
#     'date': 1480309200,
#     'formatted_date': '2016-11-28',
#     'high': 9.229999542236328,
#     'low': 8.260000228881836,
#     'open': 8.720000267028809,
#     'volume': 216332400},
#    {'adjclose': 10.34000015258789,
#     'close': 10.34000015258789,
#     'date': 1480914000,
#     'formatted_date': '2016-12-05',
#     'high': 10.65999984741211,
#     'low': 8.449999809265137,
#     'open': 8.6899995803833,
#     'volume': 343764100},
#    {'adjclose': 10.65999984741211,
#     'close': 10.65999984741211,
#     'date': 1481518800,
#     'formatted_date': '2016-12-12',
#     'high': 11.229999542236328,
#     'low': 10.270000457763672,
#     'open': 10.399999618530273,
#     'volume': 283140600},
#    {'adjclose': 11.579999923706055,
#     'close': 11.579999923706055,
#     'date': 1482123600,
#     'formatted_date': '2016-12-19',
#     'high': 11.75,
#     'low': 10.520000457763672,
#     'open': 10.8100004196167,
#     'volume': 218881800},
#    {'adjclose': 11.34000015258789,
#     'close': 11.34000015258789,
#     'date': 1482728400,
#     'formatted_date': '2016-12-26',
#     'high': 12.420000076293945,
#     'low': 11.010000228881836,
#     'open': 11.649999618530273,
#     'volume': 209834100},
#    {'adjclose': 11.319999694824219,
#     'close': 11.319999694824219,
#     'date': 1483333200,
#     'formatted_date': '2017-01-02',
#     'high': 11.6899995803833,
#     'low': 11.020000457763672,
#     'open': 11.420000076293945,
#     'volume': 169271900},
#    {'adjclose': 10.579999923706055,
#     'close': 10.579999923706055,
#     'date': 1483938000,
#     'formatted_date': '2017-01-09',
#     'high': 11.640000343322754,
#     'low': 10.329999923706055,
#     'open': 11.369999885559082,
#     'volume': 219328200},
#    {'adjclose': 9.75,
#     'close': 9.75,
#     'date': 1484542800,
#     'formatted_date': '2017-01-16',
#     'high': 10.25,
#     'low': 9.420000076293945,
#     'open': 10.170000076293945,
#     'volume': 196206900},
#    {'adjclose': 10.670000076293945,
#     'close': 10.670000076293945,
#     'date': 1485147600,
#     'formatted_date': '2017-01-23',
#     'high': 10.979999542236328,
#     'low': 9.680000305175781,
#     'open': 9.680000305175781,
#     'volume': 202260800},
#    {'adjclose': 12.239999771118164,
#     'close': 12.239999771118164,
#     'date': 1485752400,
#     'formatted_date': '2017-01-30',
#     'high': 12.65999984741211,
#     'low': 10.220000267028809,
#     'open': 10.619999885559082,
#     'volume': 433730400},
#    {'adjclose': 13.579999923706055,
#     'close': 13.579999923706055,
#     'date': 1486357200,
#     'formatted_date': '2017-02-06',
#     'high': 14.270000457763672,
#     'low': 12.380000114440918,
#     'open': 12.460000038146973,
#     'volume': 503020000},
#    {'adjclose': 13.130000114440918,
#     'close': 13.130000114440918,
#     'date': 1486962000,
#     'formatted_date': '2017-02-13',
#     'high': 13.949999809265137,
#     'low': 12.600000381469727,
#     'open': 13.699999809265137,
#     'volume': 224930200},
#    {'adjclose': 14.119999885559082,
#     'close': 14.119999885559082,
#     'date': 1487566800,
#     'formatted_date': '2017-02-20',
#     'high': 14.5,
#     'low': 13.399999618530273,
#     'open': 13.40999984741211,
#     'volume': 264468300},
#    {'adjclose': 13.029999732971191,
#     'close': 13.029999732971191,
#     'date': 1488171600,
#     'formatted_date': '2017-02-27',
#     'high': 15.550000190734863,
#     'low': 12.789999961853027,
#     'open': 14.270000457763672,
#     'volume': 578383100},
#    {'adjclose': 13.90999984741211,
#     'close': 13.90999984741211,
#     'date': 1488776400,
#     'formatted_date': '2017-03-06',
#     'high': 13.930000305175781,
#     'low': 12.380000114440918,
#     'open': 13.0,
#     'volume': 375540000},
#    {'adjclose': 13.489999771118164,
#     'close': 13.489999771118164,
#     'date': 1489377600,
#     'formatted_date': '2017-03-13',
#     'high': 14.680000305175781,
#     'low': 13.359999656677246,
#     'open': 14.479999542236328,
#     'volume': 450199300},
#    {'adjclose': 13.699999809265137,
#     'close': 13.699999809265137,
#     'date': 1489982400,
#     'formatted_date': '2017-03-20',
#     'high': 14.5,
#     'low': 13.539999961853027,
#     'open': 13.680000305175781,
#     'volume': 320007200},
#    {'adjclose': 14.550000190734863,
#     'close': 14.550000190734863,
#     'date': 1490587200,
#     'formatted_date': '2017-03-27',
#     'high': 14.75,
#     'low': 13.210000038146973,
#     'open': 13.350000381469727,
#     'volume': 246669500},
#    {'adjclose': 13.520000457763672,
#     'close': 13.520000457763672,
#     'date': 1491192000,
#     'formatted_date': '2017-04-03',
#     'high': 14.739999771118164,
#     'low': 12.829999923706055,
#     'open': 14.600000381469727,
#     'volume': 375594500},
#    {'adjclose': 12.3100004196167,
#     'close': 12.3100004196167,
#     'date': 1491796800,
#     'formatted_date': '2017-04-10',
#     'high': 13.59000015258789,
#     'low': 12.220000267028809,
#     'open': 13.520000457763672,
#     'volume': 197922600},
#    {'adjclose': 13.0,
#     'close': 13.0,
#     'date': 1492401600,
#     'formatted_date': '2017-04-17',
#     'high': 13.210000038146973,
#     'low': 12.369999885559082,
#     'open': 12.529999732971191,
#     'volume': 179517000},
#    {'adjclose': 13.300000190734863,
#     'close': 13.300000190734863,
#     'date': 1493006400,
#     'formatted_date': '2017-04-24',
#     'high': 13.760000228881836,
#     'low': 13.050000190734863,
#     'open': 13.229999542236328,
#     'volume': 190118000},
#    {'adjclose': 10.1899995803833,
#     'close': 10.1899995803833,
#     'date': 1493611200,
#     'formatted_date': '2017-05-01',
#     'high': 13.630000114440918,
#     'low': 9.850000381469727,
#     'open': 13.430000305175781,
#     'volume': 606062600},
#    {'adjclose': 11.260000228881836,
#     'close': 11.260000228881836,
#     'date': 1494216000,
#     'formatted_date': '2017-05-08',
#     'high': 11.399999618530273,
#     'low': 10.0,
#     'open': 10.220000267028809,
#     'volume': 281133400},
#    {'adjclose': 11.40999984741211,
#     'close': 11.40999984741211,
#     'date': 1494820800,
#     'formatted_date': '2017-05-15',
#     'high': 12.770000457763672,
#     'low': 10.8100004196167,
#     'open': 11.40999984741211,
#     'volume': 514081200},
#    {'adjclose': 11.0,
#     'close': 11.0,
#     'date': 1495425600,
#     'formatted_date': '2017-05-22',
#     'high': 11.550000190734863,
#     'low': 10.619999885559082,
#     'open': 11.489999771118164,
#     'volume': 236891800},
#    {'adjclose': 10.899999618530273,
#     'close': 10.899999618530273,
#     'date': 1496030400,
#     'formatted_date': '2017-05-29',
#     'high': 11.489999771118164,
#     'low': 10.569999694824219,
#     'open': 10.949999809265137,
#     'volume': 169326200},
#    {'adjclose': 12.279999732971191,
#     'close': 12.279999732971191,
#     'date': 1496635200,
#     'formatted_date': '2017-06-05',
#     'high': 13.399999618530273,
#     'low': 10.800000190734863,
#     'open': 10.84000015258789,
#     'volume': 588493500},
#    {'adjclose': 11.4399995803833,
#     'close': 11.4399995803833,
#     'date': 1497240000,
#     'formatted_date': '2017-06-12',
#     'high': 12.479999542236328,
#     'low': 11.210000038146973,
#     'open': 11.75,
#     'volume': 386439000},
#    {'adjclose': 14.170000076293945,
#     'close': 14.170000076293945,
#     'date': 1497844800,
#     'formatted_date': '2017-06-19',
#     'high': 14.670000076293945,
#     'low': 11.619999885559082,
#     'open': 11.630000114440918,
#     'volume': 718972700},
#    {'adjclose': 12.479999542236328,
#     'close': 12.479999542236328,
#     'date': 1498449600,
#     'formatted_date': '2017-06-26',
#     'high': 14.489999771118164,
#     'low': 12.359999656677246,
#     'open': 14.390000343322754,
#     'volume': 422500900},
#    {'adjclose': 13.359999656677246,
#     'close': 13.359999656677246,
#     'date': 1499054400,
#     'formatted_date': '2017-07-03',
#     'high': 13.75,
#     'low': 12.130000114440918,
#     'open': 12.569999694824219,
#     'volume': 316699200},
#    {'adjclose': 13.920000076293945,
#     'close': 13.920000076293945,
#     'date': 1499659200,
#     'formatted_date': '2017-07-10',
#     'high': 14.489999771118164,
#     'low': 13.270000457763672,
#     'open': 13.609999656677246,
#     'volume': 421672400},
#    {'adjclose': 13.880000114440918,
#     'close': 13.880000114440918,
#     'date': 1500264000,
#     'formatted_date': '2017-07-17',
#     'high': 14.119999885559082,
#     'low': 13.149999618530273,
#     'open': 14.029999732971191,
#     'volume': 300768300},
#    {'adjclose': 13.949999809265137,
#     'close': 13.949999809265137,
#     'date': 1500868800,
#     'formatted_date': '2017-07-24',
#     'high': 15.649999618530273,
#     'low': 13.680000305175781,
#     'open': 14.0,
#     'volume': 602212800},
#    {'adjclose': 13.119999885559082,
#     'close': 13.119999885559082,
#     'date': 1501473600,
#     'formatted_date': '2017-07-31',
#     'high': 14.220000267028809,
#     'low': 13.020000457763672,
#     'open': 14.09000015258789,
#     'volume': 302572200},
#    {'adjclose': 12.229999542236328,
#     'close': 12.229999542236328,
#     'date': 1502078400,
#     'formatted_date': '2017-08-07',
#     'high': 13.569999694824219,
#     'low': 11.880000114440918,
#     'open': 13.329999923706055,
#     'volume': 310358500},
#    {'adjclose': 12.369999885559082,
#     'close': 12.369999885559082,
#     'date': 1502683200,
#     'formatted_date': '2017-08-14',
#     'high': 13.1899995803833,
#     'low': 12.25,
#     'open': 12.579999923706055,
#     'volume': 271758900},
#    {'adjclose': 12.430000305175781,
#     'close': 12.430000305175781,
#     'date': 1503288000,
#     'formatted_date': '2017-08-21',
#     'high': 12.710000038146973,
#     'low': 11.859999656677246,
#     'open': 12.420000076293945,
#     'volume': 209268800},
#    {'adjclose': 13.1899995803833,
#     'close': 13.1899995803833,
#     'date': 1503892800,
#     'formatted_date': '2017-08-28',
#     'high': 13.489999771118164,
#     'low': 11.930000305175781,
#     'open': 12.529999732971191,
#     'volume': 218501400},
#    {'adjclose': 12.25,
#     'close': 12.25,
#     'date': 1504497600,
#     'formatted_date': '2017-09-04',
#     'high': 13.180000305175781,
#     'low': 12.039999961853027,
#     'open': 12.880000114440918,
#     'volume': 182331000},
#    {'adjclose': 12.520000457763672,
#     'close': 12.520000457763672,
#     'date': 1505102400,
#     'formatted_date': '2017-09-11',
#     'high': 12.739999771118164,
#     'low': 12.109999656677246,
#     'open': 12.460000038146973,
#     'volume': 222527500},
#    {'adjclose': 13.300000190734863,
#     'close': 13.300000190734863,
#     'date': 1505707200,
#     'formatted_date': '2017-09-18',
#     'high': 14.239999771118164,
#     'low': 12.739999771118164,
#     'open': 12.770000457763672,
#     'volume': 469023900},
#    {'adjclose': 12.75,
#     'close': 12.75,
#     'date': 1506312000,
#     'formatted_date': '2017-09-25',
#     'high': 13.279999732971191,
#     'low': 12.430000305175781,
#     'open': 13.25,
#     'volume': 282160600},
#    {'adjclose': 13.229999542236328,
#     'close': 13.229999542236328,
#     'date': 1506916800,
#     'formatted_date': '2017-10-02',
#     'high': 13.5,
#     'low': 12.619999885559082,
#     'open': 12.800000190734863,
#     'volume': 224955600},
#    {'adjclose': 14.220000267028809,
#     'close': 14.220000267028809,
#     'date': 1507521600,
#     'formatted_date': '2017-10-09',
#     'high': 14.40999984741211,
#     'low': 13.260000228881836,
#     'open': 13.260000228881836,
#     'volume': 243473000}],
#   'timeZone': {'gmtOffset': -18000}}}
